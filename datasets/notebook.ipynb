# %% [markdown]
# ### 1. Preparing our dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Read in track metadata with genre labels
tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')

# Read in track metrics with the features
echonest_metrics = pd.read_json('datasets/echonest-metrics.json', precise_float=True)

# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = pd.merge(echonest_metrics, tracks[['track_id' , 'genre_top']], how='inner', on='track_id')

# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %% [markdown]
# ### 2. Pairwise relationships between continuous variables

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow0_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col4 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col5 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow1_col8 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col6 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow2_col8 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col5 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col6 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col7 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow3_col8 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col6 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow5_col8 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow6_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow6_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow6_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow6_col3 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1efbd3a_b4f8_11eb_a653_b4b686e2189frow6_col5 {
#             background-color:  #eae6f1;
#             color:  #000000;

# %% [markdown]
# ### 3. Normalizing the feature data

# %%
# Define our features 
features = echo_tracks.drop(['track_id', 'genre_top'], axis=1)

# Define our labels
labels = echo_tracks.genre_top

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %% [markdown]
# ### 4. Principal Component Analysis on our scaled data¶

# %%
# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %% [markdown]
# ### 5. Further visualization of PCA

# %%
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')

# choose the n_components where about 85% of our variance can be explained
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %% [markdown]
# ### 6. Train a decision tree to classify genre

# %%
# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)

# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)

# %% [markdown]
# ### 7. Compare our decision tree to a logistic regression

# %%
# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %% [markdown]
# ### 8. Balance our data for greater performance

# %%
# Subset a balanced proportion of data points
hop_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Hip-Hop']
rock_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Rock']

# subset only the rock songs, and take a sample the same size as there are hip-hop songs
rock_only = rock_only.sample(hop_only.shape[0], random_state=10)

# concatenate the dataframes hop_only and rock_only
rock_hop_bal = pd.concat([rock_only, hop_only])

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)

# %% [markdown]
# ### 9. Does balancing our dataset improve model bias?

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier()
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression()
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_tree))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.75      0.75      0.75       230
#         Rock       0.74      0.75      0.75       225
#
#     accuracy                           0.75       455
#    macro avg       0.75      0.75      0.75       455
# weighted avg       0.75      0.75      0.75       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.75      0.75      0.75       230
#         Rock       0.74      0.75      0.75       225
#
#     accuracy                           0.75       455
#    macro avg       0.75      0.75      0.75       455
# weighted avg       0.75      0.75      0.75       455

# %% [markdown]
# ### 10. Using cross-validation to evaluate our models

# %%
# Set up our K-fold cross-validation
kf = KFold(n_splits=10)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree,pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg,pca_projection, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", tree_score, "Logistic Regression:", logit_score)
# Out:
# Decision Tree: [0.6978022  0.72527473 0.78021978 0.70879121 0.71428571 0.75274725
#  0.76923077 0.71978022 0.78021978 0.84065934] Logistic Regression: [0.76923077 0.80769231 0.82417582 0.76923077 0.76923077 0.78021978
#  0.77472527 0.74175824 0.7967033  0.7967033 ]
